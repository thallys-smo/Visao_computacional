# %% [markdown]
# ### Thallys Oliveira - Questão 2 - Lista 2

# %%
# Importanto Bibliotecas 

import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import os

# %% [markdown]
# 1. Faça a leitura da imagem borboleta.bmp.

# %%
local_img_bpm = '/home/thallys/Documentos/Graduação/Visão Computacional/Visao_computacional/Lista 2/Arquivos/borboleta.bmp'

# Lendo a imagem borboleta.bmp
img_borboleta_bpm = cv.imread(local_img_bpm)

# Convertendo a imagem borboleta.bpm para RGB
img_borboleta_bpm = cv.cvtColor(img_borboleta_bpm, cv.COLOR_BGR2RGB)

# %% [markdown]
# 2. Faça a leitura da imagem no formato .gif(borboleta.gif).

# %%
local_img_gif = '/home/thallys/Documentos/Graduação/Visão Computacional/Visao_computacional/Lista 2/Arquivos/borboleta.gif'

# Importando a imagem borboleta.gif
captura = cv.VideoCapture(local_img_gif)
ret, img_borboleta_gif = captura.read()

# Convertendo a imagem borboleta.gif para RGB
img_borboleta_gif = cv.cvtColor(img_borboleta_gif, cv.COLOR_BGR2RGB)

# %% [markdown]
# 3. Utilizando a imagem do item 1, salve-a no formato .jpg. Em seguida, leia esta imagem novamente em uma outra variável.

# %%
# Salvando a imagem borboleta.bmp para JPG
cv.imwrite('borboleta.jpg',img_borboleta_bpm)
img_borboleta_jpg = cv.imread('borboleta.jpg')

# %% [markdown]
# 4. Agora, compare o tamanho dos arquivos das imagens, imprimindo a quantidade de bytes de cada um.

# %%
# Tamanho das imagens

tam_borboleta_bpm = os.path.getsize(local_img_bpm)
tam_borboleta_gif = os.path.getsize(local_img_gif)

local_borboleta_jpg = '/home/thallys/Documentos/Graduação/Visão Computacional/Visao_computacional/Lista 2/Questão 2/borboleta.jpg'
tam_borboleta_jpg = os.path.getsize(local_borboleta_jpg)

# Imprimindo os tamanhos das imagens
print("Tamanhos das imagens borboletas")
print("Tamanho da imagem borboleta.bpm: {} bytes\n".format(tam_borboleta_bpm))
print("Tamanho da imagem borboleta.gif: {} bytes\n".format(tam_borboleta_gif))
print("Tamanho da imagem borboleta.jpg: {} bytes\n".format(tam_borboleta_jpg))
# Out:
# Tamanhos das imagens borboletas
# Tamanho da imagem borboleta.bpm: 70434 bytes
#
# Tamanho da imagem borboleta.gif: 14975 bytes
#
# Tamanho da imagem borboleta.jpg: 13505 bytes

# %% [markdown]
# 5. Apresente as três imagens lado a lado em um tamanho que seja possível observar os detalhes nos valores dos pixels

# %%
# Plotando todas as imagens juntas

plt.figure(figsize=(15, 7)) 

plt.subplot(2,3,1)
plt.imshow(img_borboleta_bpm )
plt.title('borboleta.bpm')

plt.subplot(2,3,2)
plt.imshow(img_borboleta_gif)
plt.title('borboleta.gif')

plt.subplot(2,3,3)
plt.imshow(img_borboleta_jpg)
plt.title('borboleta.jpg')

plt.show()

# %% [markdown]
# # Comentário:
#
# Premissa:
#
# - O formato BMP - Windows Bitmap. Um formato de arquivo utilizado pra simples imagens sem compressão. Guarda a informação de quantos pixels a imagem contém e a cor de cada um expressa por 3 canais, cada um podendo assumir valor de 0 a 255 (para codificação em 8 bits).
#
# - O formato JPG tem seu nome por utilizar o padrão de compressão JPEG (Joint Photographic Experts Group) para imagens de qualidade fotográfica. É um dos métodos mais populares de compactação de imagens na Internet. Seu sistema de codificação divide a imagem em blocos e os compara com padrões base da transformada discreta do cosseno (DCT) e estabelece o peso da presença de cada um desses padrões em cada bloco.
#
# - O formato GIF (Graphic Interchange Format). É freqüentemente usado para fazer pequenas animações e filmes curtos de baixa resolução para a Internet. Ideal para gráficos, logos e desenhos. Nesse padrão de compressão as cores são representadas por um conjunto de até 256 cores.
#
# Por meio da analise do tamanho em bytes das diferentes imagens 'borboletas', confirmamos  as premissas acima. A imagem com a extensão .bmp apresentou o maior tamanho e a imagem no formato .gig e .jpg, dentre as essas, a .jpg foi a menor e a .gif a intermediária. Todavia, a diferença é pequena quando quando comparamos com a imagem em .bmp, a qual é uma imagem original sem compreensão, enquanto as outras apresentam compreenções via diferentes técnicas.
#
# Por fim, observamos que nas imagens .jpg e .bmp apresentaram uma semelhança tanto nas cores, como nos seus detalhes, mas, analisando a imagem .gif, existe um "borrão" ao fundo, o que em determinadas regiões, causou o desfoque da imagem.

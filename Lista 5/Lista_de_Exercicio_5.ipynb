# %% [markdown]
# # Lista de Exercício 5
# ### Introdução à Visão Computacional (SEL0339/SEL5886)
#
# **Instruções:**
#
#  1. Esta lista consiste de 5 exercícios.
#  1. Deve-se colocar comentários nos códigos desenvolvidos.
#  1. As perguntas devem ser respondidas também como comentários no arquivo.
#  1. Colocar seu nome e número USP abaixo.
#  1. Quaisquer problemas na execução das listas, entrar em contato com os monitores.
#  1. Depois de terminado os exercícios, deve ser gerado um arquivo **extensão .ipynb** para ser enviado ao professor pelo E-DISCIPLINAS da disciplina até a data máxima de entrega.
#  1. Caso não seja enviado, o aluno ficará sem nota.
#
#
# ---
#
#
#  <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/LAVI-USP/SEL0339-SEL5886_2023/blob/main/praticas/Lista_de_Exercicio_5.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Executar no Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/blob/main/praticas/Lista_de_Exercicio_5.ipynb"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />Ver codigo fonte no GitHub</a>
#   </td>
# </table>

# %% [markdown]
# `Nome: Thallys Oliveira`
#
# `Número USP: 11819827 `

# %% [markdown]
# ### Introdução:
#
#
# Vamos importar as bibliotecas que iremos utilizar:

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
from skimage.feature import local_binary_pattern

# %% [markdown]
# #### **Atenção**: os códigos abaixo são para fazer o download das imagens (EXECUTE-OS). Os mesmos não fazem parte dessa prática.

# %%
import urllib.request

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/triangulo.png", "triangulo.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/estrela.png", "estrela.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/folha_ferrugem.png", "folha_ferrugem.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")


try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/folha_saudavel.png", "folha_saudavel.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/guitarra.png", "guitarra.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/banjo.png", "banjo.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/violao.png", "violao.png")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex3.tiff", "tex3.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex2.tiff", "tex2.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex1.tiff", "tex1.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex4.tiff", "tex4.tiff")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/circulo1.tif", "circulo1.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/circulo2.tif", "circulo2.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/quadrado1.tif", "quadrado1.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

try:
  urllib.request.urlretrieve("https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/quadrado2.tif", "quadrado2.tif")
except:
  print("[ERRO] Não foi possível fazer o download das imagens dessa prática. Entre em contato com o monitor")

# %% [markdown]
# ### 1) Momentos (Nota: 1.5/10)
#
# A equação generalizada para o cálculo do momento $m_{pq}$ é dada por:
#
# \begin{equation}
# m_{pq} = \int_{-\infty}^{\infty}\int_{-\infty}^{\infty} x^p y^q \, f(x,y) \, dx dy, \end{equation}
#
# onde $f(x,y)$ é a imagem, $x$ e $y$ suas respectivas coordenadas. Seguindo a teoria de momentos, as coordenadas do centro de massa normalizado de um objeto podem ser determinadas utilizando as seguintes equações:
#
# \begin{equation}
#   \bar{x} = \frac{m_{10}}{m_{00}}
#   \;\;\;
#   \bar{y} = \frac{m_{01}}{m_{00}}
# \end{equation}
#
# <center><figure class="half" style="display:flex">
#     <img width="256" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/triangulo.png">
#     <img width="256" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/estrela.png">
#     <figcaption><b> Figura 1: </b> Da esquerda para a direita: <i>triangulo.png</i> e <i>estrela.png</i>.</b></figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Construa uma função chamada `momentos` que, dado uma imagem de entrada, retorne todos os momentos $m_{pq}$, com p e q variando de 0 a 1, isto é, que compute os 4 momentos: $m_{00}$, $m_{01}$, $m_{10}$ e $m_{11}$;
#
# 2. Utilizando a função `momentos` e o equacionamento descrito acima, determine as coordenadas do centro de massa dos objetos das figuras `triangulo.png` e `estrela.png`.
#
# 3. Plote um '+' no centro de massa, utilizando `plt.plot` após mostrar a imagem.
# ``` python
# # Mostra a imagem
# plt.imshow(myImg, 'gray')
# # Coloca um '+' no centro de massa
# plt.plot(ic, jc, '+')
# ```
#
# 3. Rotacione a imagem `triangulo.png` em $180^{\circ}$.
#   * Para rotacionar a imagem, utilize a função [cv.rotate] passando como argumento `cv.ROTATE_180`
# ``` python
# myImg_rot = cv.rotate(myImg, cv.ROTATE_180)
# ```
#
# 4. Repita o procedimento dos itens 2 e 3. Comente a respeito.

# %%
def momentos(image):

  momento_00,momento_10,momento_01,momento_11 = 0, 0, 0, 0 #Atribuindo 0 aos momentos  
  
  for x in range(image.shape[0]):
    for y in range(image.shape[1]):
      momento_00 = momento_00 + image[x,y]     #Cálculo de M00 (p = 0 e q = 0)
      momento_10 = momento_10 + x*image[x,y]   #Cálculo de M10 (p = 1 e q = 0)
      momento_01 = momento_01 + y*image[x,y]   #Cálculo de M01 (p = 0 e q = 1)
      momento_11 = momento_11 + x*y*image[x,y] #Cálculo de M11 (p = 1 e q = 1)

  return momento_00, momento_01, momento_10, momento_11

#Importar imagens do triangulo e da estrela em RGB
img_tri = cv.imread("triangulo.png")
img_est = cv.imread("estrela.png")

#Converter imagens do triângulo e da estrela em gray scale
img_tri_g = cv.cvtColor(img_tri, cv.COLOR_BGR2GRAY)
img_est_g = cv.cvtColor(img_est, cv.COLOR_BGR2GRAY)

#Momentos m00, m10, m01 e m11 das imagens
momentos_img = []
momentos_img.append(momentos(img_tri_g))
momentos_img.append(momentos(img_est_g))

print("Momentos - Imagem Triângulo:")
print("  Momento 00: {}".format(momentos_img[0][0]))
print("  Momento 01: {}".format(momentos_img[0][1]))
print("  Momento 10: {}".format(momentos_img[0][2]))
print("  Momento 11: {}".format(momentos_img[0][3]))

print("\n")

print("Momentos - Imagem Estrela:")
print("  Momento 00: {}".format(momentos_img[1][0]))
print("  Momento 01: {}".format(momentos_img[1][1]))
print("  Momento 10: {}".format(momentos_img[1][2]))
print("  Momento 11: {}".format(momentos_img[1][3]))

# Centro de Massas das Imagens

x_tri = momentos_img[0][2]/momentos_img[0][0]
y_tri = momentos_img[0][1]/momentos_img[0][0]
x_est = momentos_img[1][2]/momentos_img[1][0]
y_est = momentos_img[1][1]/momentos_img[1][0]

#Printar e desenhar os centróides calculados (através das relaçõs m10/m00 e m01/m00)

print("Centroide triângulo = (", x_tri, ", ",y_tri,")")
print("Centroide estrela = (", x_est, ", ",x_est,")")
print("\n")

#Resultados
plt.figure(figsize = (15,15))
plt.subplot(2,2,1)
plt.imshow(img_tri_g,cmap = "gray")
plt.title("Imagem Triângulo (Escala de Cinza) - Não Rotacionado")

plt.subplot(2,2,2)
plt.imshow(img_est_g,cmap = "gray")
plt.title("Imagem Estrela Original (Escala de Cinza) - Não Rotacionado")

plt.subplot(2,2,3)
plt.imshow(img_tri)
plt.plot(x_tri,y_tri,"+")
plt.title("Imagem Triângulo com Centróide - Não Rotacionado")

plt.subplot(2,2,4)
plt.imshow(img_est)
plt.plot(x_est,y_est,"+")
plt.title("Imagem Estrela com Centróide - Não Rotacionado")

# Rotacionado as Imagems em 180

img_tri_rot = cv.rotate(img_tri, cv.ROTATE_180)
img_est_rot = cv.rotate(img_est, cv.ROTATE_180)

#Converter imagens do triângulo e da estrela em gray scale
img_tri_rot_g = cv.cvtColor(img_tri_rot, cv.COLOR_BGR2GRAY)
img_est_rot_g = cv.cvtColor(img_est_rot, cv.COLOR_BGR2GRAY)

#Momentos m00, m10, m01 e m11 das imagens
momentos_img_rot = []
momentos_img_rot.append(momentos(img_tri_rot_g))
momentos_img_rot.append(momentos(img_est_rot_g))

print("Momentos - Imagem Triângulo Rotacionado :")
print("  Momento 00: {}".format(momentos_img_rot[0][0]))
print("  Momento 01: {}".format(momentos_img_rot[0][1]))
print("  Momento 10: {}".format(momentos_img_rot[0][2]))
print("  Momento 11: {}".format(momentos_img_rot[0][3]))

print("\n")

print("Momentos - Imagem Estrela Rotacionado :")
print("  Momento 00: {}".format(momentos_img_rot[1][0]))
print("  Momento 01: {}".format(momentos_img_rot[1][1]))
print("  Momento 10: {}".format(momentos_img_rot[1][2]))
print("  Momento 11: {}".format(momentos_img_rot[1][3]))
print("\n")


# Centro de Massas das Imagens

x_tri = momentos_img_rot[0][2]/momentos_img_rot[0][0]
y_tri = momentos_img_rot[0][1]/momentos_img_rot[0][0]
x_est = momentos_img_rot[1][2]/momentos_img_rot[1][0]
y_est = momentos_img_rot[1][1]/momentos_img_rot[1][0]

print("Centroide Triângulo Rotacionado = (", x_tri, ", ",y_tri,")")
print("Centroide Estrela Rotacionado = (", x_est, ", ",x_est,")")

print("\n")

#Resultados
plt.figure(figsize = (15,15))
plt.subplot(2,2,1)
plt.imshow(img_tri_rot_g,cmap = "gray")
plt.title("Imagem Triângulo (Escala de Cinza) - Rotacionada")

plt.subplot(2,2,2)
plt.imshow(img_est_rot_g,cmap = "gray")
plt.title("Imagem Estrela Original (Escala de Cinza) - Rotacionada")

plt.subplot(2,2,3)
plt.imshow(img_tri_rot)
plt.plot(x_tri,y_tri,"+")
plt.title("Imagem Triângulo com Centróide - Rotacionada")

plt.subplot(2,2,4)
plt.imshow(img_est_rot)
plt.plot(x_est,y_est,"+")
plt.title("Imagem Estrela com Centróide - Rotacionada")
# Out:
# Momentos - Imagem Triângulo:
#   Momento 00: 2420205
#   Momento 01: 606050850
#   Momento 10: 718825365
#   Momento 11: 179963159910
#
#
# Momentos - Imagem Estrela:
#   Momento 00: 2889660
#   Momento 01: 741996705
#   Momento 10: 691411845
#   Momento 11: 177585992025
# Centroide triângulo = ( 297.0101148456432 ,  250.41302286376566 )
# Centroide estrela = ( 239.27100247087893 ,  239.27100247087893 )
#
#
# Momentos - Imagem Triângulo Rotacionado :
#   Momento 00: 2420205
#   Momento 01: 630673905
#   Momento 10: 517899390
#   Momento 11: 134917763850
#
#
# Momentos - Imagem Estrela Rotacionado :
#   Momento 00: 2889660
#   Momento 01: 734619555
#   Momento 10: 785204415
#   Momento 11: 199665131835
#
#
# Centroide Triângulo Rotacionado = ( 213.98988515435676 ,  260.58697713623434 )
# Centroide Estrela Rotacionado = ( 271.72899752912105 ,  271.72899752912105 )
# Text(0.5, 1.0, 'Imagem Estrela com Centróide - Rotacionada')

# %% [markdown]
# ### Comentários:

# %% [markdown]
# ### 2) Momentos invariantes de Hu (Nota: 2.0/10)
#
# </figure></center>
#
# **Exercício:**
#
# 1. Binarizar as imagens `guitarra.png` e `banjo.png` pelo método de Otsu. Assegure-se que o objeto seja representado como valor alto (branco) e o fundo como valor baixo (preto).
#
# 2. Realize as seguintes operações sobre a imagem:
#
#   *   Transladar a imagem em 300 pixels, tanto no eixo x quanto no eixo y;
#   *   Rotacionar a imagem em $180^{\circ}$.
#
# 3. Calcular os momentos invariantes de Hu de ambas as imagens e de suas respectivas imagens resultantes após as transformações aplicadas em (2);
#
# 4. Compare os momentos de Hu de cada imagem original com as suas versões após as operações.
#
# 5. Agora, binarize a imagem `violao.png`pelo método de Otsu. Assegure-se que o objeto seja representado como valor alto (branco) e o fundo como valor baixo (preto).
#
# 6. Calcular os momentos invariantes de Hu dessa imagem.
#
# 7. Calcule a distância euclidiana entre os vetores de momentos de Hu da imagem do violão em relação à da guitarra e do banjo (pode ser antes das operações). Com base nos resultados, os momentos de Hu foram discriminantes? Comente a respeito.
#
# Dicas:
#
# *  Utilize a função [cv.HuMoments](https://docs.opencv.org/3.4/d3/dc0/group__imgproc__shape.html#gab001db45c1f1af6cbdbe64df04c4e944) para calcular os 7 momentos invariantes de Hu. Para isso, primeiramente você precisa calcular os todos os momentos até a terceira ordem através da função [cv.moments](https://docs.opencv.org/3.4/d3/dc0/group__imgproc__shape.html#ga556a180f43cab22649c23ada36a8a139).
# ``` python
# moments = cv.moments(myImg)
# HuMoments = cv.HuMoments(moments)
# ```
#
# * Utilize a função [np.linalg.norm](https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html) da biblioteca `numpy.linalg` para calcular a distância entre os vetores.
# ``` python
# L2_distance = np.linalg.norm(momentos_de_HU_1 - momentos_de_HU_2)
# ```
#
#
# * Para rotacionar a imagem, utilize a função [cv.rotate] passando como argumento `cv.ROTATE_180`
# ``` python
# myImg_rot = cv.rotate(myImg, cv.ROTATE_180)
# ```
#
# * Para transladar a imagem, utilize a função [cv.warpAffine] passando como argumento as dimensões da imagem e uma matrix T, em que `PxX` e `PxY` correspondem às quantidades de pixel em cada dimensão.
# ``` python
# height, width = img.shape[:2]
# T = np.float32([[1, 0, PxX], [0, 1, PxY]])
# img_translad = cv.warpAffine(img, T, (width, height))
# ```

# %%
#Importar imagens em grayscale
imgGuitarra = cv.imread("guitarra.tif",0)
imgBanjo = cv.imread("banjo.tif",0)

#Binarização da imagem utilizando um determinado valor de limiar (encontrado manualmente)
retGuitarra,thrGuitarra = cv.threshold(imgGuitarra,245,255,cv.THRESH_BINARY_INV)  #binarização da guitarra
retBanjo,thrBanjo = cv.threshold(imgBanjo,245,255,cv.THRESH_BINARY_INV)  #binarização da guitarra

#Criação de uma imagem do tamanho da guitarra
imgBlackG = np.zeros([imgGuitarra.shape[0],imgGuitarra.shape[1]],np.uint8)
imgBlackB = np.zeros([imgBanjo.shape[0],imgBanjo.shape[1]],np.uint8)

#Redução da imagem da guitarra e do banjo utilizando a função resize e inserir ela na imagem de fundo do tamanho original das imagens
hg = imgGuitarra.shape[0]
wg = imgGuitarra.shape[1]
hb = imgBanjo.shape[0]
wb = imgBanjo.shape[1]
guitarraResized = cv.resize(thrGuitarra, (int(hg/4),int(wg/4)))  
banjoResized = cv.resize(thrBanjo, (int(hb/4),int(wb/4)))

imgBlackG[180:guitarraResized.shape[0]+180, 200:guitarraResized.shape[1]+200] = guitarraResized
imgBlackB[180:banjoResized.shape[0]+180, 200:banjoResized.shape[1]+200] = banjoResized

#Rotação da imagens
imgRotatedG = cv.rotate(imgBlackG, 30, preserve_range=True)
imgRotatedB = cv.rotate(imgBlackB, 30, preserve_range=True)

#Cálculo dos momentos
momentsGuitarra = cv.moments(thrGuitarra)             #momentos da imagem da guitarra sem transfomração
momentsBanjo = cv.moments(thrBanjo)                   #momentos da imagem do banjo sem transformação
momentsGuitarraTransformed = cv.moments(imgRotatedG)  #momentos da imagem da guitarra transformada
momentsBanjoTransformed = cv.moments(imgRotatedB)     #momentos da imagem do banjo transformada


#Cálculo dos momentos invariantes de HU das imagens
HuMomentsGuitarra = cv.HuMoments(momentsGuitarra)                         #momentos invariantes de HU da imagem da guitarra sem transformação
HuMomentsBanjo = cv.HuMoments(momentsBanjo)                               #momentos invariantes de HU da imagem do banjo sem transformação
HuMomentsGuitarraTransformed = cv.HuMoments(momentsGuitarraTransformed)   #momentos invariantes de HU da imagem da guitarra transformada
HuMomentsBanjoTransformed = cv.HuMoments(momentsBanjoTransformed)         #momentos invariantes de HU da imagem do banjo transformada


#Comparação dos momentos invariantes de HU
print("Imagem da Guitarra original: ",HuMomentsGuitarra)
print("Imagem da Guitarra transformada: ",HuMomentsGuitarraTransformed)
print("\n")
print("Imagem do Banjo original: ",HuMomentsBanjo)
print("Imagem do Banjo transformada: ",HuMomentsBanjoTransformed)
print("\n")
print("Imagem da Guitarra original: ",HuMomentsGuitarra)
print("Imagem do Banjo original: ",HuMomentsBanjo)
print("\n")
print("Imagem da Guitarra transformada: ",HuMomentsGuitarraTransformed)
print("Imagem do Banjo transformada: ",HuMomentsBanjoTransformed)
print("\n")

#Distância euclidiana
print("Distância euclidiana entre a guitarra original e guitarra transformada: ",np.linalg.norm(HuMomentsGuitarra - HuMomentsGuitarraTransformed))
print("Distância euclidiana entre o banjo original e banjo transformado: ",np.linalg.norm(HuMomentsBanjo - HuMomentsBanjoTransformed))
print("Distância euclidiana entre o banjo original e guitarra transformada: ",np.linalg.norm(HuMomentsBanjo - HuMomentsGuitarraTransformed))
print("Distância euclidiana entre o banjo transformado e guitarra original: ",np.linalg.norm(HuMomentsBanjoTransformed - HuMomentsGuitarra))
print("Distância euclidiana entre o banjo transformado e guitarra transformada: ",np.linalg.norm(HuMomentsBanjoTransformed - HuMomentsGuitarraTransformed))
print("Distância euclidiana entre o banjo original e guitarra original: ",np.linalg.norm(HuMomentsBanjo - HuMomentsGuitarra))
print("\n")


#Resultados
plt.figure(figsize = (12,12))
plt.subplot(3,2,1)
plt.imshow(imgGuitarra, cmap = "gray")
plt.title("Imagem da guitarra original")

plt.subplot(3,2,2)
plt.imshow(imgBanjo, cmap = "gray")
plt.title("Imagem do banjo original")

plt.subplot(3,2,3)
plt.imshow(thrGuitarra, cmap = "gray")
plt.title("Binarização da guitarra")

plt.subplot(3,2,4)
plt.imshow(thrBanjo, cmap = "gray")
plt.title("Binarização da Banjo")

plt.subplot(3,2,5)
plt.imshow(imgRotatedG, cmap = "gray")
plt.title("Imagem da guitarra transformada")

plt.subplot(3,2,6)
plt.imshow(imgRotatedB, cmap = "gray")
plt.title("Imagem do banjo transformada")


plt.show()
# Out:
# [ WARN:0@27.619] global loadsave.cpp:248 findDecoder imread_('guitarra.tif'): can't open/read file: check file path/integrity
# [ WARN:0@27.621] global loadsave.cpp:248 findDecoder imread_('banjo.tif'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 10
#       7 retBanjo,thrBanjo = cv.threshold(imgBanjo,245,255,cv.THRESH_BINARY_INV)  #binarização da guitarra
#       9 #Criação de uma imagem do tamanho da guitarra
# ---> 10 imgBlackG = np.zeros([imgGuitarra.shape[0],imgGuitarra.shape[1]],np.uint8)
#      11 imgBlackB = np.zeros([imgBanjo.shape[0],imgBanjo.shape[1]],np.uint8)
#      13 #Redução da imagem da guitarra e do banjo utilizando a função resize e inserir ela na imagem de fundo do tamanho original das imagens
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# ### 3) Assinaturas (Nota: 2.0/10)
#
# <center><figure class="half" style="display:flex">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/circulo1.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/circulo2.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/quadrado1.png">
#     <img width="128" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/quadrado2.png">
#     <figcaption><b> Figura 3: </b> Da esquerda para a direita: <i>circulo1.tif</i>, <i>circulo2.tif</i>, <i>quadrado1.tif</i> e <i>quadrado2.tif</i>.</b></figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Utilize a função chamada `assinatura` que plota a assinatura de um contorno a partir do seu centro de massa ($\bar{x}$   e $\bar{y}$ calculados no exercício 1);
#
# 2. Aplique essa função para as imagens:
#
#   *   `circulo1.tif`
#   *   `circulo2.tif`
#   *   `quadrado1.tif`
#   *   `quadrado2.tif`
#
# 3. Mostre o resultado utilizando um `subplot` de tamanho (1,2), onde o primeiro deve mostrar a imagem original e o segundo a respectiva assinatura.
#   * Estipule os valores de escala mostrados abaixo (função `plt.axis`) para os eixos `rho` e `theta` ao plotar cada uma das assinaturas.
#   ```python
#   plt.plot(theta,rho,'.')
#   plt.axis([-180, 180, 0, 150])
#   plt.show()
#   ```
#
#
# 4. Além disso, plote um '+' no centro de massa da imagem.
#
# 5. Compare e comente os resultados obtidos.
#
# 6. Com base nos resultados referente aos círculos, o que se pode concluir em relação à função assinatura e a forma como detecta a borda/fronteira do objeto?
#
# <b>Dicas:</b>
#
#
# * Mostre o *plote* da assinatura com "pontos", utilizando a função `plt.plot` com o argumento ` '.' ` . Veja o exemplo abaixo.
# ``` python
# rho,theta = assinatura(img,cX,cY)
# plt.plot(rho,theta,'.')
# ```
#
# * Para colocar um '+' no centro de massa, utilize um `plt.plot` após mostrar a imagem.
# ``` python
# # Mostra a imagem
# plt.imshow(myImg, 'gray')
# # Coloca um '+' no centro de massa
# plt.plot(ic, jc, '+')
# ```

# %%
def assinatura(img, ic, jc):
  '''
  Descrição: Cria assinatura para uma imagem.

  Entrada:
    - img: Imagem de entrada (uint8).
    - ic: Coordenada X do centro de massa normalizado (uint8).
    - jc: Coordenada Y do centro de massa normalizado (uint8).
  
  Saída:
    - rho: Coordenadas polar (rho) dos pontos [range=0:img.shape[0]*np.sqrt(2)/2].
    - theta: Coordenadas polar (theta) dos pontos [range=-180:180].
  '''
  # Sistema de coordenadas
  # .__> jj (y)
  # |   
  # v
  # ii (x)

  # Teste de insanidade
  if img.ndim != 2:
    raise ValueError('Imagem deve ter 2 dimensões.')

  # Varre a imagem, determinando as coordenadas dos pontos brancos
  ii,jj = np.nonzero(img)

  # Translada a origem do sistema de coordenadas para o centro de massa
  ii -= int(ic)
  jj -= int(jc)

  # Converte as novas coordenadas cartesianas para coordenadas polares
  rho = np.sqrt(ii**2 + jj**2)
  theta = np.rad2deg(np.arctan2(jj, ii))

  return rho, theta


## -- Seu código começa AQUI -- ##
#Importar as imagens em grayscale
img1 = cv.imread("circulo1.tif",0)
img2 = cv.imread("circulo2.tif",0)
img3 = cv.imread("quadrado1.tif",0)
img4 = cv.imread("quadrado2.tif",0)



#Função para o cálculo dos momentos
(m00_1,m10_1,m01_1, m11_1) = momentos(img1)
(m00_2,m10_2,m01_2, m11_2) = momentos(img2)
(m00_3,m10_3,m01_3, m11_3) = momentos(img3)
(m00_4,m10_4,m01_4, m11_4) = momentos(img4)

#Cálculo dos centróides (xi,yi)
x1 = np.uint8(m10_1/m00_1)
y1 = np.uint(m01_1/m00_1)

x2 = m10_2/m00_2
y2 = m01_2/m00_2

x3 = m10_3/m00_3
y3 = m01_3/m00_3

x4 = m10_4/m00_4
y4 = m01_4/m00_4

#Aplicação da função assinatura
rho1, theta1 = assinatura(img1,x1,y1)
rho2, theta2 = assinatura(img2,x2,y2)
rho3, theta3 = assinatura(img3,x3,y3)
rho4, theta4 = assinatura(img4,x4,y4)

#Resultados
plt.figure(figsize = (15,15))
plt.subplot(4,2,1)
plt.imshow(img1,cmap = 'gray')
plt.plot(x1,y1,'+')
plt.title("circulo1")

plt.subplot(4,2,2)
plt.plot(theta1,rho1,'.')
plt.title("assinatura circulo1")

plt.subplot(4,2,3)
plt.imshow(img2,cmap = 'gray')
plt.plot(x2,y2,'+')
plt.title("circulo2")

plt.subplot(4,2,4)
plt.plot(theta2,rho2,'.')
plt.title("assinatura circulo2")

plt.subplot(4,2,5)
plt.imshow(img3,cmap = 'gray')
plt.plot(x3,y3,'+')
plt.title("quadrado1")

plt.subplot(4,2,6)
plt.plot(theta3,rho3,'.')
plt.title("assinatura quadrado1")

plt.subplot(4,2,7)
plt.imshow(img4,cmap = 'gray')
plt.plot(x4,y4,'+')
plt.title("quadrado2")

plt.subplot(4,2,8)
plt.plot(theta4,rho4,'.')
plt.title("assinatura quadrado2")

plt.show()

# %% [markdown]
# #### Comentários:
#
# Através da função "momentos", construída no exercício 1, para se encontrar as coordenadas dos centróides da imagens dos círculos e dos quadrados foi possível gerar a assinatura do contorno das figuras. A função para se construir as assinaturas consiste em duas principais etapas: a translação da origem do sistema de coordenadas dos pixels para o centróide das figuras e posteriormente a conversão das coordenadas cartesianas em polares para realizar uma varredura radial ao redor da imagem, resultando nos gráficos das assinaturas mostrados acima. Pelas assinaturas geradas, é possível perceber que elas variam a aparência e a periodicidade dos pontos plotados de acordo com a posição do centróide das imagens, assim como de acordo com o formato das figuras e a grossura dos contornos

# %% [markdown]
# ### 4) *Local Binnary Patterns* (LBP) (Nota: 2.0/10)
#
# <center><figure class="half" style="display:flex">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex1.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex2.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex3.png">
#     <img width="200" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/tex4.png">
#     <figcaption><b> Figura 4: </b> Da esquerda para a direita: feijão, macarrão, arroz e arroz novamente.</figcaption>
# </figure></center>
#
# **Exercício:**
#
# 1. Calcule os mapas de textura por padrões binários locais (LBP) das imagens apresentadas anteriormente. Cada uma representa a imagem de um alimento (feijão, macarrão, arroz). Considere raio 1 e 8 vizinhos, e utilize o método por 'default': LBP circular original;
#
# 2. Apresente os mapas de texturas calculados (imagens) e o histograma correpondente a cada um;
#
# 3. Carregue a imagem `tex4.tiff`, e também apresente o seu mapa de textura e o seu histograma LBP.
#
# 4. Calcule a distância euclidiana **entre os histogramas** LBP de cada imagem e o **histograma** da imagem `tex4.tiff`. A distância euclidiana nesse caso está sendo utilizada como métrica de similaridade. Classifique a qual dos três tipos de textura a imagem `tex4.tiff` pertence;
#
# 4. Varie o raio, o número de pontos e o método utilizado para o 'rot': versão que lida com variação da rotação; e verifique como a distância entre os histogramas varia, se descrevem melhor as amostras da mesma classe.
#
#
# <font size="3" color="darkblue"><b>Dicas:</b></font>
#
#
# * Utilize a função [local_binary_pattern](https://scikit-image.org/docs/dev/api/skimage.feature.html?highlight=lbp#skimage.feature.local_binary_pattern) da biblioteca `scikit-image.feature` para calcular o LBP.
#
# * Utilize a função [np.linalg.norm](https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html) da biblioteca `numpy.linalg` para calcular a distância entre os vetores.
#
# *Ex:*
# ``` python
# # P correspondendo aos pontos e R ao raio.
# image_LBP = local_binary_pattern(myImg, P, R, method='default')
#
# L2_distance = np.linalg.norm(vetor_diferenca_entre_histogramas)
# ```

# %%
#Importar imagens
img_fe = cv.imread("tex1.tiff",0)   #Imagem feijão
img_ma = cv.imread("tex2.tiff",0)   #Imagem macarrão
img_a1 = cv.imread("tex3.tiff",0)   #Imagem arroz
img_a2 = cv.imread("tex4.tiff",0)   #Imagem arroz

#Cálculo dos mapas de texturas por padrões binários locasis, com 8 pontos e raio unitário
LBP_fe = local_binary_pattern(img_fe, 8, 1, method='default')
LBP_ma = local_binary_pattern(img_ma, 8, 1, method='default')
LBP_a1 = local_binary_pattern(img_a1, 8, 1, method='default')
LBP_a2 = local_binary_pattern(img_a2, 8, 1, method='default')


#Cálculo dos histogramas
hist_fe = np.histogram(LBP_fe, bins=80, range= (0,255), density=False)
hist_ma = np.histogram(LBP_ma, bins=80, range= (0,255), density=False)
hist_a1 = np.histogram(LBP_a1, bins=80, range= (0,255), density=False)
hist_a2 = np.histogram(LBP_a2, bins=80, range= (0,255), density=False)



#Cálculo das distâncias euclidianas entre as imagens do feijão, macarrão e do arroz
print("Distâncias euclidianas dos histogramas do LBP das imagens")
print("Distância euclidiana entre Feijão e macarrão: " ,np.linalg.norm(hist_fe[0]-hist_ma[0]))
print("Distância euclidiana entre Feijão e arroz1: "   ,np.linalg.norm(hist_fe[0]-hist_a1[0]))
print("Distância euclidiana entre Macarrão e arroz 1: ",np.linalg.norm(hist_fe[0]-hist_ma[0]))
print("Distância euclidiana entre Feijão e arroz 2: "  ,np.linalg.norm(hist_fe[0]-hist_a2[0]))
print("Distância euclidiana entre Macarrão e arroz 2: ",np.linalg.norm(hist_ma[0]-hist_a2[0]))
print("Distância euclidiana entre Arroz 1 e arroz 2: " ,np.linalg.norm(hist_a1[0]-hist_a2[0]))
print("\n")


#Cálculo dos mapas de texturas por padrões binários locais, variando os parâmetros para 12 pontos e raio igual a 3
LBP2_feijao   = local_binary_pattern(img_fe, 12, 3, method='ror')
LBP2_macarrao = local_binary_pattern(img_ma, 12, 3, method='ror')
LBP2_arroz1   = local_binary_pattern(img_a1, 12, 3, method='ror')
LBP2_arroz2   = local_binary_pattern(img_a2, 12, 3, method='ror')

#Cálculo dos histogramas
hist2_feijao = np.histogram(LBP2_feijao, bins=80, range= (0,255), density=False)
hist2_macarrao = np.histogram(LBP2_macarrao, bins=80, range= (0,255), density=False)
hist2_arroz1 = np.histogram(LBP2_arroz1, bins=80, range= (0,255), density=False)
hist2_arroz2 = np.histogram(LBP2_arroz2, bins=80, range= (0,255), density=False)


#Cálculo das distâncias euclidianas entre as imagens do feijão, macarrão e do arroz com os parâmetros de LBP modificados
print("Distâncias euclidianas dos histogramas do LBP das imagens com parâmetros modificados")
print("Distância euclidiana entre Feijão e macarrão: ",np.linalg.norm(hist2_feijao[0]-hist2_macarrao[0]))
print("Distância euclidiana entre Feijão e arroz1: ",np.linalg.norm(hist2_feijao[0]-hist2_arroz1[0]))
print("Distância euclidiana entre Macarrão e arroz 1: ",np.linalg.norm(hist2_feijao[0]-hist2_macarrao[0]))
print("Distância euclidiana entre Feijão e arroz 2: ",np.linalg.norm(hist2_feijao[0]-hist2_arroz2[0]))
print("Distância euclidiana entre Macarrão e arroz 2: ",np.linalg.norm(hist2_macarrao[0]-hist2_arroz2[0]))
print("Distância euclidiana entre Arroz 1 e arroz 2: ",np.linalg.norm(hist2_arroz1[0]-hist2_arroz2[0]))
print("\n")




#Resultados
plt.figure(figsize = (15,15))
plt.subplot(4,3,1)
plt.imshow(img_fe,cmap = 'gray')
plt.title("Imagem do feijão original")

plt.subplot(4,3,2)
plt.imshow(LBP_fe,cmap = 'gray')
plt.title("LBP do feijão")

plt.subplot(4,3,3)
plt.hist(LBP_fe.flatten(),bins=80,density=False,range=(0,255))
plt.title("Histograma LBP do feijão")


plt.subplot(4,3,4)
plt.imshow(img_ma,cmap = 'gray')
plt.title("Imagem do macarrão original")

plt.subplot(4,3,5)
plt.imshow(LBP_ma,cmap = 'gray')
plt.title("LBP do macarrão")

plt.subplot(4,3,6)
plt.hist(LBP_ma.flatten(),bins=80,density=False,range=(0,255))
plt.title("Histograma LBP do macarrão")

plt.subplot(4,3,7)
plt.imshow(img_a1,cmap = 'gray')
plt.title("Imagem do arroz 1 original")

plt.subplot(4,3,8)
plt.imshow(LBP_a1,cmap = 'gray')
plt.title("LBP do arroz 1")

plt.subplot(4,3,9)
plt.hist(LBP_a1.flatten(),bins=80,density=False,range=(0,255))
plt.title("Histograma LBP do arroz 1")


plt.subplot(4,3,10)
plt.imshow(img_a2,cmap = 'gray')
plt.title("Imagem do arroz 2 original")

plt.subplot(4,3,11)
plt.imshow(LBP_a2,cmap = 'gray')
plt.title("LBP do arroz 2")

plt.subplot(4,3,12)
plt.hist(LBP_a2.flatten(),bins=80,density=False,range=(0,255))
plt.title("Histograma LBP do arroz 2")

plt.show()
# Out:
# Distâncias euclidianas dos histogramas do LBP das imagens
# Distância euclidiana entre Feijão e macarrão:  5617.441588481362
# Distância euclidiana entre Feijão e arroz1:  5130.36645864601
# Distância euclidiana entre Macarrão e arroz 1:  5617.441588481362
# Distância euclidiana entre Feijão e arroz 2:  4643.3212251577
# Distância euclidiana entre Macarrão e arroz 2:  2583.9647830417503
# Distância euclidiana entre Arroz 1 e arroz 2:  1053.9240959386022
#
#
# Distâncias euclidianas dos histogramas do LBP das imagens com parâmetros modificados
# Distância euclidiana entre Feijão e macarrão:  10430.436999474183
# Distância euclidiana entre Feijão e arroz1:  7011.555176991764
# Distância euclidiana entre Macarrão e arroz 1:  10430.436999474183
# Distância euclidiana entre Feijão e arroz 2:  6940.937544741344
# Distância euclidiana entre Macarrão e arroz 2:  3587.136462416784
# Distância euclidiana entre Arroz 1 e arroz 2:  393.87053710578556

# %% [markdown]
# ### Comentários:
#
# Computando-se os mapas de texturas por padrões binários locais (LBP) das imagens das comidas e posteriormente os histogramas destes mapas para se gerar descritores de textura das imagens, foi calculado a distância euclidiana como métrica de similaridade entre cada dois descritores gerados. Desta maneira, foi possível encontar que a textura da segunda imagem do arroz apresentou uma maior semelhança à textura da primeira imagem do arroz, o que resultou em uma coerência já que as duas imagens eram de um mesmo alimento, apesar delas serem diferentes. A comparação de similaridade do descritor de textura do arroz com o descritor do macarrão e do feijão, assim como a comparação dos descritores do feijão com o do macarrão apresentaram valores distantes, mostrando algo esperado já que eles são alimentos diferentes que por consequência possuem texturas distintas.
#
# Alterando-se o raio de 1 para 3 e o número de pontos vizinhos de 8 para 12 do método que realiza a aplicação do mapa de texturas, foi possível obter descritores a partir dos histogramas destes mapas que apresentaram um maior valor de similaridade entre as imagens do arroz e um menor valor de similaridade entre alimentos diferentes, comparado com as diferenças obtidas entre os descritores com a utilização do LBP com raio 1 e 8 pontos vizinhos.

# %% [markdown]
# ### 5) Descritor de cor (Nota: 2.5/10)
#
# Esse exercício tem como objetivo obter um descritor sobre as folhas de café.
#
#
#
#  <center><figure class="half" style="display:flex">
#     <img width="300" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/folha_ferrugem.png">
#     <img width="300" src="https://github.com/LAVI-USP/SEL0339-SEL5886_2023/raw/main/imagens/pratica_05/folha_saudavel.png">
#  </figure>
#     <figcaption><b> Figura 5: </b> Da esquerda para a direita: Folha com ferrugem  e folha saudável.</figcaption>
# </center>
#
#
# 1. Extraia os canais R, G e B da imagem `folha_ferrugem.png`;
#
# 2. Como a ferrugem, nesse caso, possui pigmentação alaranjada, os canais R e G possuirão altos valores de intensidade nos pontos de ferrugem enquanto que o canal B terá baixos valores de intensidade.
#
# 3. Visualize os canais R, G e B separadamente, em escala de cinza.
#
# 4. Proponha, então, uma máscara binária $M(x)$ para os canais R, G e B (separadamente) de forma que, ao fazer alguma operação lógica com essas três máscaras dos canais, seja possível obter uma máscara que contenha os pixels de iteresse (ferrugem).
#   * Você deve propor os thresholds bem como a operação lógica.
#
# 3. Mostre cada matriz binária dos canais e a resultante da operação.
#
# 4. Por fim, faça um descritor para a relação entre pixel de ferrugem $P_{fr}$ e pixel de folha $P_{fl}$:
#
#   \begin{equation}
#   Cor_{\gamma}(\%) = \frac{P_{fr}}{P_{fl}}
#   \end{equation}
#
# 5. Agora, aplique exatamente o mesmo passo a passo que você propôs anteriormente na imagem `folha_saudavel.png`. Seu descritor foi bem sucessido? Comente.

# %%
#Importando imagens originais
img_d = cv.imread('folha_ferrugem.png')
img_s = cv.imread('folha_saudavel.png')

#Converter BGR to RGB
img_d = cv.cvtColor(img_d,cv.COLOR_BGR2RGB)
img_s = cv.cvtColor(img_s,cv.COLOR_BGR2RGB)

#Extração dos canais R, G e B da imagem
(R_d,G_d,B_d) = cv.split(img_d) # Canais RGB da imagem da folha doente
(R_s,G_s,B_s) = cv.split(img_s) # Canais RGB da imagem da folha saldável

#Matrizes para armazenar as máscaras ds canais R, G e B
MR_d = np.zeros([img_d.shape[0],img_d.shape[1]],dtype = np.uint8)  #mascara para o canal R - Folha Doente
MG_d = np.zeros([img_d.shape[0],img_d.shape[1]],dtype = np.uint8)  #mascara para o canal B - Folha Doente
MB_d = np.zeros([img_d.shape[0],img_d.shape[1]],dtype = np.uint8)  #mascara para o canal G - Folha Doente

MR_s = np.zeros([img_s.shape[0],img_s.shape[1]],dtype = np.uint8)  #mascara para o canal R - Folha Doente
MG_s = np.zeros([img_s.shape[0],img_s.shape[1]],dtype = np.uint8)  #mascara para o canal B - Folha Doente
MB_s = np.zeros([img_s.shape[0],img_s.shape[1]],dtype = np.uint8)  #mascara para o canal G - Folha Doente


# Realizando binarização dos canais R, G e B

for row in range (img_d.shape[0]):
  for col in range(img_d.shape[1]):
    if R_d[row,col] >= 200:
      MR_d[row,col] = 255
      MR_s[row,col] = 255

    if G_d[row,col] >= 200:
      MG_d[row,col] = 255
      MG_s[row,col] = 255

    if B_d[row,col] <= 100:
      MB_d[row,col] = 255 
      MB_s[row,col] = 255 


# Mascara Resultando - Multiplicação das máscaras de R, G e B - Identificação da Ferrugem na Folha
Mascara_R_d = MR_d*MG_d*MB_d  # Mascara da Folha Doente
Mascara_R_s = MR_s*MG_s*MB_s  # Mascara da Folha Saldável

''' Descritor de cor ''' 

# Converter imagem original para grayscale
img_d_gray = cv.cvtColor(img_d, cv.COLOR_RGB2GRAY)     
img_s_gray = cv.cvtColor(img_s, cv.COLOR_RGB2GRAY)        

# Binarizar imagem da planta para criar uma masácara inteira dela

ret_d,mp_d = cv.threshold(img_d_gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU)  
ret_s,mp_s = cv.threshold(img_s_gray,0,255,cv.THRESH_BINARY_INV+cv.THRESH_OTSU) 

# Complemento da máscara
mp_d_comp = cv.bitwise_not(mp_d)       
mp_s_comp = cv.bitwise_not(mp_s)   

#Variável que armazena o número de pixels total da folha 
#Variável que armazena o número de pixels da ferrugem da folha

Pfl_d, Pfr_d = 0,0    # Folha Doente 
Pfl_s, Pfr_s = 0,0    # Folha Saldável
         
for row in range (img_d.shape[0]):
  for col in range(img_d.shape[1]):
    if(mp_d_comp[row,col] > 0):
      Pfl_d = Pfl_d + 1
    if(mp_s_comp[row,col] > 0):
      Pfl_s = Pfl_s + 1      
    if(Mascara_R_d[row,col] > 0):
      Pfr_d = Pfr_d + 1
    if(Mascara_R_s[row,col] > 0):
      Pfr_s = Pfr_s + 1
      

print("Folha Defeituosa: Cory(%) = ",(Pfr_d/Pfl_d) * 100)
print("Folha Saldável: Cory(%) = ",(Pfr_s/Pfl_s) * 100)

#Resultados
plt.figure(figsize = (15,8))
plt.subplot(3,4,1)
plt.imshow(img_d)
plt.title("Folha Doente - Imagem original")

plt.subplot(3,4,2)
plt.imshow(R_d, cmap = 'gray')
plt.title("Folha Doente - Canal R")

plt.subplot(3,4,3)
plt.imshow(G_d, cmap = 'gray')
plt.title("Folha Doente - Canal G")

plt.subplot(3,4,4)
plt.imshow(B_d, cmap = 'gray')
plt.title("Folha Doente - Canal B")


plt.subplot(3,4,5)
plt.imshow(MR_d, cmap = 'gray')
plt.title("Folha Doente - Máscara canal R")


plt.subplot(3,4,6)
plt.imshow(MG_d, cmap = 'gray')
plt.title("Folha Doente - Máscara canal G")

plt.subplot(3,4,7)
plt.imshow(MB_d, cmap = 'gray')
plt.title("Folha Doente - Máscara canal B")

plt.subplot(3,4,8)
plt.imshow(Mascara_R_d, cmap = 'gray')
plt.title("Folha Doente - Máscara resultante")

plt.subplot(3,4,9)
plt.imshow(mp_d_comp, cmap = 'gray')
plt.title("Folha Doente - Máscara da planta")

#Resultados
plt.figure(figsize = (15,8))
plt.subplot(3,4,1)
plt.imshow(img_s)
plt.title("Folha Saldável - Imagem original")

plt.subplot(3,4,2)
plt.imshow(R_s, cmap = 'gray')
plt.title("Folha Saldável - Canal R")

plt.subplot(3,4,3)
plt.imshow(G_s, cmap = 'gray')
plt.title("Folha Saldável - Canal G")

plt.subplot(3,4,4)
plt.imshow(B_s, cmap = 'gray')
plt.title("Folha Saldável - Canal B")


plt.subplot(3,4,5)
plt.imshow(MR_s, cmap = 'gray')
plt.title("Folha Saldável - Máscara canal R")


plt.subplot(3,4,6)
plt.imshow(MG_s, cmap = 'gray')
plt.title("Folha Saldável - Máscara canal G")

plt.subplot(3,4,7)
plt.imshow(MB_s, cmap = 'gray')
plt.title("Folha Saldável - Máscara canal B")

plt.subplot(3,4,8)
plt.imshow(Mascara_R_s, cmap = 'gray')
plt.title("Folha Saldável - Máscara resultante")

plt.subplot(3,4,9)
plt.imshow(mp_s_comp, cmap = 'gray')
plt.title("Folha Saldável - Máscara da planta")
# Out:
# Folha Defeituosa: Cory(%) =  5.629348513598988
# Folha Saldável: Cory(%) =  6.283868462393871
# Text(0.5, 1.0, 'Folha Saldável - Máscara da planta')

# %% [markdown]
# ### Comentários:
#
# Separando-se os canais R, G e B da imagem original, foi possível observar o fato de que a ferrugem na folha possuia pixels somente nos canais R e G, já que ela é da cor amarela. Binarizando-se cada uma das imagens de cada canal, conforme as relações dadas no enunciado do exercício, foi possível identificar nas imagens dos canais R e G a região que apresentava uma maior quantidade de pixels que possuiam ferrugem, enquanto que para o canal B foi identificado a região da folha que possuia pontos pretos que equivaliam à ferrugem, já que para a cor amarela não há a influência do canal B da imagem, que por consequência faz aparecer pixels pretos nos locais da ferrugem. Assim, com a binarização de cada um dos canais para a identificação das regiões com a maior probabilidade da existência de pixels equivalente à ferrugem, foi realizado uma operação "and" entre as três imagens para resultar em uma única imagem que possuia pixels referentes à ferrugem em pontos coincidentes, conforme é mostrado no plot da figura "Mascara resultante". Binarizando-se a imagem original da folha utilizando o método de otsu, para segmentar a região correspondente à folha inteira, conforme é possível observar no plot "Máscara da planta", foi possível computar a percentagem de pixels de ferrugem presente em toda a folha, de modo a construir um descritor de cor que separasse folhas saudáveis de folhas não saudávei
